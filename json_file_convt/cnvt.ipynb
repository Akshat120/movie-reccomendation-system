# %%
import pandas as pd

# %%
# !ls
# Out:
# 2023-04-16-04-33-10.json Untitled.ipynb

# %%
tweets_df = pd.read_json('2023-04-16-04-33-10.json', lines=True)

# %%
len(tweets_df)
# Out:
# 6015

# %%
c=0
url_lst=[]
for i in range(len(tweets_df)):
    try:
        url_lst.append(tweets_df['card'][i]['url'])
    except:
        c=c+1
        url_lst.append('url not exists')
        print("An exception occurred")
        print(url_lst.append(tweets_df['card'][i]))
# Out:
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# An exception occurred
# None
# ...

# %%
c
# Out:
# 95

# %%
url_lst
# Out:
# ['https://www.imdb.com/title/tt8368406',
#  'https://www.imdb.com/title/tt1692486',
#  'https://www.imdb.com/title/tt4425200',
#  'https://www.imdb.com/title/tt2911666',
#  'https://www.imdb.com/title/tt0730422',
#  'https://www.imdb.com/title/tt8114980',
#  'https://www.imdb.com/title/tt0089686',
#  'https://www.imdb.com/title/tt11145118',
#  'https://www.imdb.com/title/tt7037712',
#  'https://www.imdb.com/title/tt10151854',
#  'https://www.imdb.com/title/tt3748420',
#  'url not exists',
#  'https://www.imdb.com/title/tt2906216',
#  'https://www.imdb.com/title/tt13223398/',
#  'https://www.imdb.com/title/tt16419074',
#  'https://www.imdb.com/title/tt0042876',
#  'https://www.imdb.com/title/tt1809398',
#  'https://www.imdb.com/title/tt15767808',
#  'https://www.imdb.com/title/tt8749198',
#  'https://www.imdb.com/title/tt22667880',
#  'https://www.imdb.com/title/tt2872718',
#  'https://www.imdb.com/title/tt4846340',
#  'https://www.imdb.com/title/tt10192406',
# ...

# %%
tweets_df['imdb_links']=url_lst

# %%
tweets_df
# Out:
#                                _type  \
# 0     snscrape.modules.twitter.Tweet
# 1     snscrape.modules.twitter.Tweet
# 2     snscrape.modules.twitter.Tweet
# 3     snscrape.modules.twitter.Tweet
# 4     snscrape.modules.twitter.Tweet
# ...                              ...
# 6010  snscrape.modules.twitter.Tweet
# 6011  snscrape.modules.twitter.Tweet
# 6012  snscrape.modules.twitter.Tweet
# 6013  snscrape.modules.twitter.Tweet
# 6014  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/gustavoseifer/status/16473...
# 1     https://twitter.com/gustavoseifer/status/16473...
# 2     https://twitter.com/DamoAdonisSmart/status/164...
# 3     https://twitter.com/OpenAirScreen/status/16473...
# 4     https://twitter.com/imdbmap/status/16473677309...
# ...                                                 ...
# 6010  https://twitter.com/dapperdan75/status/1627462...
# 6011  https://twitter.com/marcb__/status/16274625095...
# ...
